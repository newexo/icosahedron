# %%
from langchain_community.llms import Ollama

# %%
from icosahedron.campaign.names import NameGenerator

# %%
llm = Ollama(model="gemma2", temperature=0)

# %%
generator = NameGenerator(llm=llm)

# %%
j = generator.generate(number=30)
print(j)
# Out:
# [
#   {
#     "name": "Alaric",
#     "etymology": "From the Germanic name meaning 'all-powerful ruler', popularized by the Visigothic king Alaric I.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Baldwin",
#     "etymology": "From the Germanic name meaning 'bold friend', a common name in medieval Europe.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Bran",
#     "etymology": "From the Welsh name meaning 'raven', often associated with wisdom and magic.",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Cassian",
#     "etymology": "From the Latin name meaning 'hollow', possibly referring to a valley or a person of noble character.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Cormac",
#     "etymology": "From the Irish name meaning 'charioteer', often associated with strength and leadership.",
#     "origin": "Irish",
#     "gender": "male"
#   },
#   {
# ...

# %%
llm = Ollama(model="mistral-nema", temperature=0)

# %%
j = generator.generate(number=30)
print(j)
# Out:
# [
#   {
#     "name": "Alaric",
#     "etymology": "From the Germanic name meaning 'all-powerful ruler', popularized by the Visigothic king Alaric I.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Baldwin",
#     "etymology": "From the Germanic name meaning 'bold friend', a common name in medieval Europe.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Bran",
#     "etymology": "From the Welsh name meaning 'raven', often associated with wisdom and magic.",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Cassian",
#     "etymology": "From the Latin name meaning 'hollow', possibly referring to a valley or a person of noble character.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Cormac",
#     "etymology": "From the Irish name meaning 'charioteer', often associated with strength and leadership.",
#     "origin": "Irish",
#     "gender": "male"
#   },
#   {
# ...
