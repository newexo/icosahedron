# %%
from langchain_community.llms import Ollama

# %%
from icosahedron.campaign.names_generator import NameGenerator

# %%
llm = Ollama(model="gemma2", temperature=0)
generator = NameGenerator(llm=llm)

# %%
j = generator.generate(number=10)
print(j)
# Out:
# [
#   {
#     "name": "Alaric",
#     "etymology": "Derived from the Germanic elements 'al' meaning 'all' and 'rīks' meaning 'ruler', signifying 'all-ruler'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Gareth",
#     "etymology": "From the Welsh name 'Geraint', meaning 'gentle' or 'strong'.",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Cassian",
#     "etymology": "Latin name meaning 'hollow' or 'empty', possibly referring to a type of valley or a person of noble bearing.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Eamon",
#     "etymology": "Irish form of 'Edmund', meaning 'wealthy protector' or 'prosperous guardian'.",
#     "origin": "Irish",
#     "gender": "male"
#   },
#   {
#     "name": "Ronan",
#     "etymology": "Irish name meaning 'little seal' or 'seal-king'.",
#     "origin": "Irish",
#     "gender": "male"
#   },
#   {
#     "name": "Lysander",
# ...

# %%
llm = Ollama(model="mistral-nemo", temperature=0)
generator = NameGenerator(llm=llm)

# %%
j = generator.generate(number=10)
print(j)
# Out:
# [
#   {
#     "name": "Eadgar",
#     "etymology": "Derived from Old English 'ead' meaning 'wealth' and '-gar', a suffix meaning 'spear'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Godfrey",
#     "etymology": "Composed of the Germanic elements 'god' meaning 'god' and '-frid' meaning 'peace'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Lothar",
#     "etymology": "Derived from Old High German 'hlud', meaning 'famous', and '-hari', meaning 'army'.",
#     "origin": "Old High German",
#     "gender": "male"
#   },
#   {
#     "name": "Roland",
#     "etymology": "Composed of the Germanic elements 'hrod' meaning 'fame' and '-land', a suffix meaning 'land'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Theodoric",
#     "etymology": "Derived from Old High German 'theudo', meaning 'people', and '-ric', meaning 'power'.",
#     "origin": "Old High German",
# ...

# %%
j = generator.generate(culture="Fantasy world based on ancient Chinese history", number=10)
print(j)
# Out:
# [
#   {
#     "name": "Li Wei",
#     "etymology": "Li means 'plum' and Wei means 'powerful', reflecting the strength and resilience of the plum tree.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Zhang Fei",
#     "etymology": "Zhang means 'exalted' and Fei means 'fly', symbolizing freedom and independence.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Sun Wukong",
#     "etymology": "Sun means 'monkey', Wu means 'awaken', Kong means 'empty', referring to the monkey king's awakening from stone.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Guan Yu",
#     "etymology": "Guan means 'observe' and Yu means 'easy', suggesting a character who is easy to observe or understand.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Lu Bu",
# ...

# %%
j = generator.generate(culture="Dark elf from the Underdark", number=10)
print(j)
# Out:
# [
#   {
#     "name": "Zor'ak",
#     "etymology": "Derived from 'Zor', meaning 'dark', and 'ak', meaning 'shadow'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Drákon",
#     "etymology": "From 'Draco', Latin for 'dragon', reflecting the reverence for these creatures.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Kael'thas",
#     "etymology": "Combines 'Kael', meaning 'hidden', and 'thas', meaning 'power'.",
#     "origin": "Underdark Elvish",
#     "gender": "male"
#   },
#   {
#     "name": "Vex'aria",
#     "etymology": "From 'Vex', meaning 'confuse', and 'aria', meaning 'song'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Malakor",
#     "etymology": "'Mala' meaning 'evil', and 'kor', meaning 'heart'.",
#     "origin": "Underdark Orcish",
#     "gender": "male"
#   },
#   {
#     "name": "Eolande",
# ...

# %%
j = generator.generate(culture="Dwarven (mountain dwarf)", number=10)
print(j)
# Out:
# [
#   {
#     "name": "Drogthar Stonebeard",
#     "etymology": "Derived from Old Dwarvish 'drogh' meaning 'strong' and 'thar' meaning 'heart', combined with 'Stonebeard', a traditional dwarven name suffix.",
#     "origin": "Old Dwarvish",
#     "gender": "male"
#   },
#   {
#     "name": "Grimnir Ironfist",
#     "etymology": "'Grimnir' means 'masked one' in Old Dwarvish, and 'Ironfist' is a common name suffix among dwarven warriors.",
#     "origin": "Old Dwarvish",
#     "gender": "male"
#   },
#   {
#     "name": "Kazad Dín",
#     "etymology": "'Kazad' means 'dwarf' and 'Dín' means 'friend' in Sindarin, the language of the Elves.",
#     "origin": "Sindarin",
#     "gender": "male"
#   },
#   {
#     "name": "Thoren Stonehelm",
#     "etymology": "'Thoren' is derived from Old Dwarvish 'thor' meaning 'thunder' and 'Stonehelm', a traditional dwarven name suffix.",
#     "origin": "Old Dwarvish",
#     "gender": "male"
#   },
#   {
#     "name": "Bolg Deepdelver",
# ...

# %%
j = generator.generate(culture="Dwarven (mountain dwarf)", gender="female", number=10)
print(j)
# Out:
# [
#   {
#     "name": "Drogthar Stoneheart",
#     "etymology": "Derived from Old Dwarvish 'drog' meaning 'iron' and 'thar' meaning 'strong', reflecting her unyielding nature.",
#     "origin": "Dwarven",
#     "gender": "female"
#   },
#   {
#     "name": "Glimmer Goldvein",
#     "etymology": "'Glimmer' is derived from Old Dwarvish 'glimma' meaning 'spark', and 'Goldvein' refers to her family's rich mining heritage.",
#     "origin": "Dwarven",
#     "gender": "female"
#   },
#   {
#     "name": "Kazad Dinsdelver",
#     "etymology": "'Kazad' is derived from Old Dwarvish 'kaz' meaning 'dig', and 'Dinsdelver' refers to her family's history of deep mining.",
#     "origin": "Dwarven",
#     "gender": "female"
#   },
#   {
#     "name": "Morgwyn Stonebeard",
#     "etymology": "'Morgwyn' is derived from Old Dwarvish 'morg' meaning 'dark' and 'gwyn' meaning 'white', reflecting her dual nature, and 'Stonebeard' is a traditional family name.",
#     "origin": "Dwarven",
# ...
