# %%
from langchain_community.llms import Ollama

# %%
from icosahedron.campaign.names import NameGenerator

# %%
llm = Ollama(model="gemma2", temperature=0)
generator = NameGenerator(llm=llm)

# %%
j = generator.generate(number=30)
print(j)
# Out:
# [
#   {
#     "name": "Alaric",
#     "etymology": "From the Germanic *al-*, meaning 'all', and *rīks*, meaning 'ruler', signifying 'all-ruler'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Baldwin",
#     "etymology": "From the Old French *baldwin*, meaning 'bold friend', a combination of *bald* (bold) and *win* (friend).",
#     "origin": "French",
#     "gender": "male"
#   },
#   {
#     "name": "Cassian",
#     "etymology": "From the Latin *cassianus*, meaning 'hollow' or 'empty', possibly referring to a type of valley or a person of noble bearing.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Conrad",
#     "etymology": "From the Germanic *kunrat*, meaning 'bold counsel' or 'brave advice', a combination of *kunn* (bold) and *rat* (advice).",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Eamon",
#     "etymology": "From the Irish *Éamonn*, meaning 'wealthy protector' or 'rich guardian', a combination of *eam* (wealth) and *mon* (protector).",
#     "origin": "Irish",
#     "gender": "male"
#   },
#   {
#     "name": "Edgar",
#     "etymology": "From the Old English *ēadgar*, meaning 'wealthy spear', a combination of *ēad* (wealth) and *gar* (spear).",
#     "origin": "English",
#     "gender": "male"
#   },
#   {
#     "name": "Gareth",
#     "etymology": "From the Welsh *Gareth*, meaning 'gentle' or 'lord', a combination of *gar* (gentle) and *eth* (lord).",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Griffin",
#     "etymology": "From the Welsh *grifîn*, meaning 'strong lord' or 'fierce protector', a mythical creature with the head and wings of an eagle and the body of a lion.",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Harold",
#     "etymology": "From the Old English *hēarold*, meaning 'army ruler' or 'leader of the host', a combination of *hēar* (army) and *old* (ruler).",
#     "origin": "English",
#     "gender": "male"
#   },
#   {
#     "name": "Hugh",
#     "etymology": "From the Germanic *Hugh*, meaning 'mind' or 'intellect', a name associated with wisdom and intelligence.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Ivor",
# "etymology": "From the Welsh *Ifor*, meaning 'archer' or 'bowman', a name associated with skill and precision.",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Jasper",
#     "etymology": "From the Persian *yaspar*, meaning 'treasurer' or 'bringer of treasure', a name associated with wealth and prosperity.",
#     "origin": "Persian",
#     "gender": "male"
#   },
#   {
#     "name": "Leon",
#     "etymology": "From the Latin *leo*, meaning 'lion', a name associated with courage, strength, and nobility.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Magnus",
#     "etymology": "From the Latin *magnus*, meaning 'great' or 'large', a name associated with power, influence, and grandeur.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Milo",
#     "etymology": "From the Slavic *Miloš*, meaning 'dear' or 'beloved', a name associated with affection, kindness, and gentleness.",
#     "origin": "Slavic",
#     "gender": "male"
#   },
#   {
#     "name": "Nigel",
#     "etymology": "From the Old French *Nigel*, meaning 'champion' or 'victorious', a name associated with bravery, strength, and success.",
#     "origin": "French",
#     "gender": "male"
#   },
#   {
#     "name": "Owen",
#     "etymology": "From the Welsh *Owain*, meaning 'noble' or 'well-born', a name associated with honor, dignity, and respect.",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Percival",
#     "etymology": "From the French *Perceval*, meaning 'piercer of the valley', a name associated with chivalry, courage, and adventure.",
#     "origin": "French",
#     "gender": "male"
#   },
#   {
#     "name": "Rhys",
#     "etymology": "From the Welsh *Rhys*, meaning 'ardor' or 'fiery', a name associated with passion, energy, and determination.",
#     "origin": "Welsh",
#     "gender": "male"
#   },
#   {
#     "name": "Rowan",
#     "etymology": "From the Gaelic *ruadhán*, meaning 'little redhead', a name associated with strength, resilience, and wisdom.",
#     "origin": "Gaelic",
#     "gender": "male"
#   },
#   {
#     "name": "Silas",
#     "etymology": "From the Latin *Silas*, meaning 'wood' or 'forest', a name associated with nature, tranquility, and mystery.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Tristan",
#     "etymology": "From the Cornish *Trystan*, meaning 'sorrowful' or 'sad', a name associated with love, loss, and tragedy.",
#     "origin": "Cornish",
#     "gender": "male"
#   },
#   {
#     "name": "Victor",
#     "etymology": "From the Latin *victor*, meaning 'conqueror' or 'winner', a name associated with success, triumph, and victory.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "William",
#     "etymology": "From the Germanic *Wilhelm*, meaning 'resolute protector' or 'strong-willed warrior', a combination of *wil* (will) and *helm* (protection).",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Arthur",
#     "etymology": "From the Celtic *Arturius*, meaning 'bear king' or 'noble bear', a name associated with strength, courage, and leadership.",
#     "origin": "Celtic",
#     "gender": "male"
#   },
#   {
#     "name": "Frederick",
#     "etymology": "From the Germanic *Friedrich*, meaning 'peaceful ruler' or 'powerful ruler', a combination of *fridu* (peace) and *rīks* (ruler).",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Alexander",
#     "etymology": "From the Greek *Alexandros*, meaning 'defender of men', a name associated with bravery, strength, and leadership.",
#     "origin": "Greek",
#     "gender": "male"
#   },
#   {
#     "name": "Thomas",
#     "etymology": "From the Aramaic *Thomas*, meaning 'twin' or 'doubter', a name associated with intelligence, questioning, and faith.",
#     "origin": "Aramaic",
#     "gender": "male"
#   }
# ]

# %%
llm = Ollama(model="mistral-nemo", temperature=0)
generator = NameGenerator(llm=llm)

# %%
j = generator.generate(number=30)
print(j)
# Out:
# [
#   {
#     "name": "Alaric",
#     "etymology": "Derived from the Germanic elements 'alaz' meaning 'noble' and 'ric' meaning 'power'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Baldwin",
#     "etymology": "Composed of the Germanic elements 'bald' meaning 'bold' or 'brave' and 'win' meaning 'friend'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Cedric",
#     "etymology": "Derived from the Old English name 'Cerdic', which was likely derived from the Germanic element 'hard' meaning 'strong or hardy'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Edgar",
#     "etymology": "Derived from the Old English name 'Eadgar', which was composed of the elements 'ead' meaning 'wealth, fortune' and 'gar' meaning 'spear'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Egbert",
#     "etymology": "Derived from the Old English name 'Ecgberht', which was composed of the elements 'ecg' meaning 'dagger' and 'beorht' meaning 'bright'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Ethelred",
#     "etymology": "Derived from the Old English name 'Æþelræd', which was composed of the elements 'æþel' meaning 'noble' and 'ræd' meaning 'counsel'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Godfrey",
#     "etymology": "Derived from the Germanic name 'Gautvid', which was composed of the elements 'gauda' meaning 'god' and 'wit' meaning 'wood'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Godwin",
#     "etymology": "Derived from the Old English name 'Godwine', which was composed of the elements 'god' meaning 'god' and 'wine' meaning 'friend'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Gundulf",
#     "etymology": "Derived from the Germanic name 'Gundulf', which was composed of the elements 'gund' meaning 'war' and 'wulf' meaning 'wolf'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Harold",
#     "etymology": "Derived from the Old Norse name 'Háraldr', which was composed of the elements 'hár' meaning 'army' and 'valdr' meaning 'power'.",
#     "origin": "Old Norse",
#     "gender": "male"
#   },
#   {
#     "name": "Hubert",
#     "etymology": "Derived from the Germanic name 'Hugbert', which was composed of the elements 'hug' meaning 'heart, mind' and 'berht' meaning 'bright'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Leofric",
#     "etymology": "Derived from the Old English name 'Léofríc', which was composed of the elements 'léof' meaning 'dear, beloved' and 'ríc' meaning 'power'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Ludwig",
#     "etymology": "Derived from the Germanic name 'Hludwig', which was composed of the elements 'hlud' meaning 'famous' and 'wig' meaning 'war'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Magnus",
#     "etymology": "Derived from the Latin name 'Magnus', which means 'great'.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Maldred",
#     "etymology": "Derived from the Old English name 'Mælðrède', which was composed of the elements 'mæl' meaning 'council, assembly' and 'þréo' meaning 'three'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Odo",
#     "etymology": "Derived from the Germanic name 'Audo', which was composed of the elements 'auda' meaning 'wealth, fortune' and '-o' a diminutive suffix.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Osbert",
#     "etymology": "Derived from the Old English name 'Ósbeorht', which was composed of the elements 'ós' meaning 'god' and 'beorht' meaning 'bright'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Ralph",
#     "etymology": "Derived from the Old Norse name 'Raðulfr', which was composed of the elements 'ráð' meaning 'counsel, advice' and 'ulfr' meaning 'wolf'.",
#     "origin": "Old Norse",
#     "gender": "male"
#   },
#   {
#     "name": "Reginald",
#     "etymology": "Derived from the Germanic name 'Rægenhild', which was composed of the elements 'rægin' meaning 'power, counsel' and '-hild' a feminine suffix.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Richard",
#     "etymology": "Derived from the Germanic name 'Ricard', which was composed of the elements 'ric' meaning 'power, rich' and '-ard' a diminutive suffix.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Roland",
#     "etymology": "Derived from the Germanic name 'Hrodland', which was composed of the elements 'hrod' meaning 'fame, glory' and 'land'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Sigmund",
#     "etymology": "Derived from the Germanic name 'Sigmund', which was composed of the elements 'sigi' meaning 'victory' and 'munt' meaning 'protection'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Theobald",
#     "etymology": "Derived from the Germanic name 'Dietpold', which was composed of the elements 'diot' meaning 'people' and 'polt' meaning 'bold'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Thorne",
#     "etymology": "Derived from the Old English name 'Þórn', which means 'thorn bush'.",
#     "origin": "Old English",
#     "gender": "male"
#   },
#   {
#     "name": "Tristan",
#     "etymology": "Derived from the Celtic name 'Drustan', which was likely derived from the elements 'drust' meaning 'noise, tumult' and '-an' a suffix.",
#     "origin": "Celtic",
#     "gender": "male"
#   },
#   {
#     "name": "Ulric",
#     "etymology": "Derived from the Germanic name 'Wulfric', which was composed of the elements 'wulf' meaning 'wolf' and 'ric' meaning 'power'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Walther",
#     "etymology": "Derived from the Germanic name 'Walthari', which was composed of the elements 'walh' meaning 'foreign, Roman' and '-hari' a suffix.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Wilfred",
#     "etymology": "Derived from the Old English name 'Wiþgar', which was composed of the elements 'wiþ' meaning 'wide, loud' and '-gar' a suffix.",
#     "origin": "Old English",
#     "gender": "male"
#   }
# ]

# %%
j = generator.generate(culture="Fantasy world based on ancient Chinese history")
print(j)
# Out:
# [
#   {
#     "name": "Li Wei",
#     "etymology": "Li means 'plum' and Wei means 'powerful', reflecting the power and resilience of the plum tree.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Zhao Yu",
#     "etymology": "Zhao means 'beginning' and Yu means 'easy', suggesting a life filled with ease from the start.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Sun Wukong",
#     "etymology": "Sun means 'monkey', Wukong means 'awaken to emptiness', referring to his awakening and enlightenment.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Huang Di",
#     "etymology": "Huang means 'yellow' and Di means 'emperor', referring to the legendary Yellow Emperor, a cultural hero.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Qin Shi Huang",
#     "etymology": "Qin is the state of Qin, Shi means 'beginning' and Huang means 'emperor', referring to the first emperor of China.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Guan Yu",
#     "etymology": "Guan means 'watchtower' and Yu means 'easy', suggesting a life filled with ease while being vigilant.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Lu Bu",
#     "etymology": "Lu means 'deer' and Bu means 'not', referring to his fearlessness like a deer that doesn't flee.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Zhang Fei",
#     "etymology": "Zhang means 'exalted' and Fei means 'fly', suggesting a life of high aspirations and freedom.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Zhuge Liang",
#     "etymology": "Zhuge means 'wisdom' and Liang means 'bright', referring to his intelligence and wisdom.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Xiao Ao Jiang Hu",
#     "etymology": "Xiao means 'small', Ao means 'wave', Jiang means 'river' and Hu means 'lakes and seas', suggesting a life of freedom like the waves on vast waters.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Lan Caihe",
#     "etymology": "Lan means 'orchid' and Caihe means 'plucked from the valley', suggesting a life of beauty plucked from obscurity.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Liang Shanbo",
#     "etymology": "Liang means 'bright' and Shanbo means 'mountain village', suggesting a life filled with brightness in the mountains.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Hei Ba",
#     "etymology": "Hei means 'black' and Ba means 'eight', referring to his status as one of the Eight Immortals.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Han Xiangzi",
#     "etymology": "Han is a surname, Xiang means 'fragrance' and Zi means 'son', suggesting a life filled with fragrance like the plum blossom.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Lv Dongbin",
#     "etymology": "Lv means 'green' and Dongbin means 'eastern peak', suggesting a life of growth and enlightenment at the eastern peak.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Cao Cao",
#     "etymology": "Cao means 'harsh' or 'rough', reflecting his stern and unyielding nature.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Sun Ce",
#     "etymology": "Sun means 'monkey' and Ce means 'to grasp', suggesting a life of grasping power like a monkey grasping its tail.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Liu Bei",
#     "etymology": "Liu means 'sixth' and Bei means 'north', referring to his status as the ruler of the northern state of Shu Han.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Gongsun Zan",
#     "etymology": "Gongsun means 'clan' and Zan means 'to establish', suggesting a life of establishing his clan's power.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Yuan Shao",
#     "etymology": "Yuan means 'source' or 'beginning' and Shao means 'small', suggesting a life filled with small beginnings.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Dong Zhuo",
#     "etymology": "Dong means 'east' and Zhuo means 'violent', reflecting his violent nature as a warlord.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Lu Xun",
#     "etymology": "Lu means 'deer' and Xun means 'to follow', suggesting a life of following the path of the deer, symbolizing grace and freedom.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Su Shi",
#     "etymology": "Su means ' Empty' or 'void' and Shi means 'poetry', suggesting a life filled with empty poetry.",
#     "origin": "Chinese",
#     "gender": "male"
#   }
# ]

# %%
j = generator.generate(culture="Dark elf from the Underdark")
print(j)
# Out:
# [
#   {
#     "name": "Zor'ak",
#     "etymology": "Derived from 'Zor', meaning 'dark', and 'ak', meaning 'shadow'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Keth'Ran",
#     "etymology": "'Keth' means 'blood', and 'Ran' means 'moon'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Drul'Kah",
#     "etymology": "'Drul' means 'stone', and 'Kah' means 'heart'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Vex'Thar",
#     "etymology": "'Vex' means 'chaos', and 'Thar' means 'god'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Grom'Tor",
#     "etymology": "'Grom' means 'thunder', and 'Tor' means 'path'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Mal'Kor",
#     "etymology": "'Mal' means 'evil', and 'Kor' means 'king'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Rath'Gor",
#     "etymology": "'Rath' means 'war', and 'Gor' means 'mountain'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Syth'Il",
#     "etymology": "'Syth' means 'poison', and 'Il' means 'eye'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Thul'Bak",
#     "etymology": "'Thul' means 'death', and 'Bak' means 'spirit'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Xul'Kra",
#     "etymology": "'Xul' means 'darkness', and 'Kra' means 'power'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Yor'Gun",
#     "etymology": "'Yor' means 'demon', and 'Gun' means 'warrior'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Zeph'Ral",
#     "etymology": "'Zeph' means 'whisper', and 'Ral' means 'magic'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Drago'Thar",
#     "etymology": "'Drago' means 'dragon', and 'Thar' means 'god'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Eolande",
#     "etymology": "Derived from the Underdark Drow word for 'shadow walker'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Grom'Gul",
#     "etymology": "'Grom' means 'thunder', and 'Gul' means 'cave'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Kael'Dor",
#     "etymology": "'Kael' means 'darkness', and 'Dor' means 'gift'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Loth'Ran",
#     "etymology": "'Loth' means 'death', and 'Ran' means 'moon'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Malkor",
#     "etymology": "Derived from the Underdark Draconic word for 'evil king'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Nath'Rak",
#     "etymology": "'Nath' means 'snake', and 'Rak' means 'venom'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Orthax",
#     "etymology": "Derived from the Underdark Draconic word for 'iron heart'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Pell'dor",
#     "etymology": "'Pell' means 'shadow', and 'Dor' means 'gift'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Qaelum",
#     "etymology": "Derived from the Underdark Draconic word for 'dark hunter'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Rath'Gor",
#     "etymology": "'Rath' means 'war', and 'Gor' means 'mountain'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Syth'Il",
#     "etymology": "'Syth' means 'poison', and 'Il' means 'eye'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Thul'Bak",
#     "etymology": "'Thul' means 'death', and 'Bak' means 'spirit'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Xul'Kra",
#     "etymology": "'Xul' means 'darkness', and 'Kra' means 'power'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   },
#   {
#     "name": "Yor'Gun",
#     "etymology": "'Yor' means 'demon', and 'Gun' means 'warrior'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Zeph'Ral",
#     "etymology": "'Zeph' means 'whisper', and 'Ral' means 'magic'.",
#     "origin": "Underdark Drow",
#     "gender": "male"
#   }
# ]
