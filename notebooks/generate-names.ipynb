# %%
from langchain_community.llms import Ollama

# %%
from icosahedron.campaign.names import NameGenerator

# %%
llm = Ollama(model="gemma2", temperature=0)
generator = NameGenerator(llm=llm)

# %%
j = generator.generate(number=30)
print(j)
# Out:
# [
#   {
#     "name": "Alaric",
#     "etymology": "From the Germanic *al-", meaning 'all', and *-rīks', meaning 'ruler', signifying 'all-ruler'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Baldwin",
#     "etymology": "From the Old French *bald-", meaning 'bold', and *-win', meaning 'friend', signifying 'bold friend'.",
#     "origin": "French",
#     "gender": "male"
#   },
#   {
#     "name": "Cassian",
#     "etymology": "From the Latin *cassianus', meaning 'hollow' or 'empty', possibly referring to a type of valley or a person of humble origins.",
#     "origin": "Latin",
#     "gender": "male"
#   },
#   {
#     "name": "Conrad",
#     "etymology": "From the Germanic *kunrat', meaning 'bold counsel' or 'brave advice'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Eamon",
#     "etymology": "From the Irish *Éamonn', meaning 'wealthy protector' or 'rich guardian'.",
#     "origin": "Irish",
# ...

# %%
llm = Ollama(model="mistral-nemo", temperature=0)
generator = NameGenerator(llm=llm)

# %%
j = generator.generate(number=30)
print(j)
# Out:
# [
#   {
#     "name": "Alaric",
#     "etymology": "Derived from the Germanic elements 'all' meaning 'any' and 'rīc' meaning 'power'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Baldwin",
#     "etymology": "Composed of the Germanic elements 'bald' meaning 'bold' and 'wine' meaning 'friend'.",
#     "origin": "French (Norman)",
#     "gender": "male"
#   },
#   {
#     "name": "Cedric",
#     "etymology": "Derived from the Old English name 'Cerdic', which means 'natural leader or warrior'.",
#     "origin": "English",
#     "gender": "male"
#   },
#   {
#     "name": "Dietrich",
#     "etymology": "Composed of the Germanic elements 'thiod' meaning 'people' and 'rīc' meaning 'power'.",
#     "origin": "Germanic",
#     "gender": "male"
#   },
#   {
#     "name": "Eadgar",
#     "etymology": "Derived from the Old English name 'Ēadgār', which means 'wealth spear'.",
#     "origin": "English",
#     "gender": "male"
#   },
#   {
#     "name": "Fulk",
# ...

# %%
j = generator.generate(culture="Fantasy world based on ancient Chinese history")
print(j)
# Out:
# [
#   {
#     "name": "Li Wei",
#     "etymology": "Li means 'plum' and Wei means 'powerful', reflecting the strength and resilience of the plum tree.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Wang Yu",
#     "etymology": "Wang means 'king' or 'ruler' and Yu means 'elegant', suggesting a refined and noble character.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Xiao Ming",
#     "etymology": "Xiao means 'small' and Ming means 'bright', implying a young person with a promising future.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Zhao Kun",
#     "etymology": "Zhao means 'beginning' or 'start' and Kun means 'kindness', suggesting a compassionate leader.",
#     "origin": "Chinese",
#     "gender": "male"
#   },
#   {
#     "name": "Sun Wukong",
#     "etymology": "Sun means 'monkey', Wu means 'awaken', Kong means 'empty', referring to the Monkey King from Journey to the West.",
# ...

# %%
j = generator.generate(culture="Dark elf from the Underdark")
print(j)
# Out:
# [
#   {
#     "name": "Zor'ak",
#     "etymology": "Derived from 'Zor', meaning 'dark', and 'ak', meaning 'shadow'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Drákon",
#     "etymology": "From the Underdark Draconic word 'drákon', meaning 'dragon'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Keth'Ran",
#     "etymology": "'Keth' means 'blood', and 'Ran' means 'moon'.",
#     "origin": "Underdark Elvish",
#     "gender": "male"
#   },
#   {
#     "name": "Vex'thor",
#     "etymology": "'Vex' means 'chaos', and 'thor' means 'god of war'.",
#     "origin": "Underdark Draconic",
#     "gender": "male"
#   },
#   {
#     "name": "Eolande",
#     "etymology": "From the Underdark Elvish word 'eol', meaning 'twilight', and '-ande' suffix.",
#     "origin": "Underdark Elvish",
#     "gender": "male"
#   },
#   {
#     "name": "Grom'thar",
# ...

# %%
j = generator.generate(culture="Dwarven (mountain dwarf)")
print(j)
# Out:
# [
#   {
#     "name": "Drogthar",
#     "etymology": "Derived from Old Norse 'dróttinn' meaning 'lord' and 'þórr' meaning 'Thor'.",
#     "origin": "Old Norse",
#     "gender": "male"
#   },
#   {
#     "name": "Grimnir",
#     "etymology": "From Old Norse 'grímnir', meaning 'the masked one'.",
#     "origin": "Old Norse",
#     "gender": "male"
#   },
#   {
#     "name": "Kveldulf",
#     "etymology": "Derived from Old Norse 'kvöld' meaning 'evening' and 'ulfr' meaning 'wolf'.",
#     "origin": "Old Norse",
#     "gender": "male"
#   },
#   {
#     "name": "Bjornar",
#     "etymology": "From Old Norse 'bjôrn' meaning 'bear' and 'arr' meaning 'warrior'.",
#     "origin": "Old Norse",
#     "gender": "male"
#   },
#   {
#     "name": "Erikr",
#     "etymology": "Derived from Old Norse 'eiðr' meaning 'eternal'.",
#     "origin": "Old Norse",
#     "gender": "male"
#   },
#   {
#     "name": "Frostbeard",
# ...

# %%
j = generator.generate(culture="Dwarven (mountain dwarf)", gender="female")
print(j)
# Out:
# [
#   {
#     "name": "Bronwyn",
#     "etymology": "Derived from the Old Welsh 'bron' meaning 'breast' and 'gwen' meaning 'white', suggesting purity.",
#     "origin": "Welsh",
#     "gender": "female"
#   },
#   {
#     "name": "Eira",
#     "etymology": "Taken from the Welsh word for 'snow', reflecting the cold, mountainous terrain.",
#     "origin": "Welsh",
#     "gender": "female"
#   },
#   {
#     "name": "Gwenhwyfar",
#     "etymology": "A combination of the Old Welsh words 'gwen' meaning 'white' and 'hwyar' meaning 'smooth', suggesting elegance.",
#     "origin": "Welsh",
#     "gender": "female"
#   },
#   {
#     "name": "Mair",
#     "etymology": "Derived from the Welsh word for 'sea', reflecting the dwarven connection to ancient maritime traditions.",
#     "origin": "Welsh",
#     "gender": "female"
#   },
#   {
#     "name": "Rhiannon",
#     "etymology": "Meaning 'great queen' in Welsh, reflecting the powerful female figures in dwarven history.",
# ...
